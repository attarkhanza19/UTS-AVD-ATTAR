# %% [markdown]
# # **FORMULA 1 PITSTOP PERFORMANCE**

# %% [markdown]
# # IMPORT LIBRARY

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # DATA FRAME

# %%
path = "/content/drive/MyDrive/GOOGLE COLLAB AVD/DATASHEET/pitstops.csv"

df = pd.read_csv(path)

df
# Out:
#       RaceId  DriverId  Stops  Year       Race  No         DriverName Code  \
# 0        258       100      1  1994    pacific  20         Erik Comas  COM
# 1        258        79      1  1994    pacific   3      Ukyo Katayama  KAT
# 2        258        57      1  1994    pacific   7      Mika Hakkinen  HAK
# 3        258        71      1  1994    pacific   0         Damon Hill  HIL
# 4        258       105      1  1994    pacific  24   Michele Alboreto  ALB
# ...      ...       ...    ...   ...        ...  ..                ...  ...
# 9916     355        18      1  2010  abu-dhabi   1      Jenson Button  BUT
# 9917     355        10      1  2010  abu-dhabi  24         Timo Glock  GLO
# 9918     355         5      1  2010  abu-dhabi  19  Heikki Kovalainen  KOV
# 9919     355         9      1  2010  abu-dhabi  11      Robert Kubica  KUB
# 9920     355        16      1  2010  abu-dhabi  14       Adrian Sutil  SUT
#
#                        Car  Lap TimeOfDay    Time   Total
# ...

# %%
df.head(20)
# Out:
#     RaceId  DriverId  Stops  Year     Race  No             DriverName Code  \
# 0      258       100      1  1994  pacific  20             Erik Comas  COM
# 1      258        79      1  1994  pacific   3          Ukyo Katayama  KAT
# 2      258        57      1  1994  pacific   7          Mika Hakkinen  HAK
# 3      258        71      1  1994  pacific   0             Damon Hill  HIL
# 4      258       105      1  1994  pacific  24       Michele Alboreto  ALB
# 5      258        91      1  1994  pacific  29        Karl Wendlinger  WEN
# 6      258        44      1  1994  pacific  26          Olivier Panis  PAN
# 7      258        94      1  1994  pacific  23      Pierluigi Martini  MAR
# 8      258        30      1  1994  pacific   5     Michael Schumacher  MSC
# 9      258       104      1  1994  pacific   9   Christian Fittipaldi  FIT
# 10     258        50      1  1994  pacific   6         Jos Verstappen  VER
# ...

# %%
df.tail(20)
# Out:
#       RaceId  DriverId  Stops  Year       Race  No          DriverName Code  \
# 9901     355       153      1  2010  abu-dhabi  17   Jaime Alguersuari  ALG
# 9902     355       811      1  2010  abu-dhabi  21         Bruno Senna  SEN
# 9903     355       810      1  2010  abu-dhabi  25     Lucas di Grassi  DIG
# 9904     355        32      1  2010  abu-dhabi  20     Christian Klien  KLI
# 9905     355        17      1  2010  abu-dhabi   6         Mark Webber  WEB
# 9906     355        13      1  2010  abu-dhabi   7        Felipe Massa  MAS
# 9907     355         4      1  2010  abu-dhabi   8     Fernando Alonso  ALO
# 9908     355         2      1  2010  abu-dhabi  22       Nick Heidfeld  HEI
# 9909     355        22      1  2010  abu-dhabi   9  Rubens Barrichello  BAR
# 9910     355         1      1  2010  abu-dhabi   2      Lewis Hamilton  HAM
# 9911     355        20      1  2010  abu-dhabi   5    Sebastian Vettel  VET
# ...

# %% [markdown]
# # BUSINESS UNDERSTANDING

# %% [markdown]
# ##Study Case

# %% [markdown]
# Dalam balapan Formula One, pit stop merupakan salah satu strategi penting yang dapat menentukan kemenangan tim. Pit stop yang terlalu lama dapat menyebabkan pembalap kehilangan posisi, sedangkan pit stop yang cepat dan tepat waktu dapat meningkatkan peluang menang.

# %% [markdown]
# ##Business Objective

# %% [markdown]
# Business objective-nya adalah untuk membantu *racing team* meningkatkan performa dan efisiensi strategi pit stop dengan menganalisis *history* pit stop agar dapat mencapai waktu pit stop secepat mungkin dan mendapatkan *placement* terbaik mereka setelah balapan berakhir.

# %% [markdown]
# Data ini berisi data pit stop dari balapan Formula One. Data tersebut mencatat informasi tentang pembalap, tim, lap saat pit stop dilakukan, jumlah pit stop, serta durasi waktu pit stop selama balapan.

# %% [markdown]
# # Assess Situation

# %% [markdown]
# Tim sering kesulitan menentukan strategi pit stop terbaik. Banyak hal yang harus dipertimbangkan, seperti berapa kali pit stop, kapan waktu yang tepat untuk pit stop, dan berapa lama durasinya. Karena itu, diperlukan analisis data pit stop sebelumnya untuk melihat pola dan menentukan strategi yang paling efisien.

# %% [markdown]
# ##Analytic Goals dan Project Plan

# %% [markdown]
# Analytic Goals
#
#
#
# 1. Menganalisis data pit stop pada balapan Formula One untuk memahami strategi pit stop yang paling efisien.
# 2. Mengetahui tim dan pembalap dengan durasi pit stop paling cepat.
# 3. Menghitung rata-rata waktu pit stop setiap tim dan pembalap.
# 4. Menganalisis hubungan antara jumlah pit stop dengan total waktu pit stop.
# 5. Mengetahui lap yang paling sering digunakan untuk pit stop.
# 6. Menemukan pola strategi pit stop yang dapat meningkatkan efisiensi waktu balapan.
# 7. Memberikan insight dan rekomendasi strategi pit stop yang optimal berdasarkan data.
#
# Project Plans
#
# 1. Memahami dataset dengan membaca dan mengecek isi data seperti pembalap, tim, lap pit stop, dan durasi.
# 2. Melakukan pembersihan data
# 3. Menyiapkan data agar siap dianalisis.
# 4. Melakukan eksplorasi data dengan menghitung rata-rata durasi pit stop tiap tim dan pembalap.
# 5. Menganalisis distribusi jumlah pit stop dan pola pit stop berdasarkan lap.
# 6. Membuat visualisasi data agar lebih mudah dipahami.
# 7. Membandingkan performa pit stop antar tim dan pembalap.
# 8. Menentukan strategi pit stop yang paling efisien berdasarkan hasil analisis.
# 9. Menarik kesimpulan dan memberikan insight dari hasil analisis data.

# %% [markdown]
# #Data Understanding

# %% [markdown]
# ##Deskripsi Data

# %% [markdown]
# ###Informasi Dasar

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9921 entries, 0 to 9920
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RaceId      9921 non-null   int64
#  1   DriverId    9921 non-null   int64
#  2   Stops       9921 non-null   int64
#  3   Year        9921 non-null   int64
#  4   Race        9921 non-null   object
#  5   No          9921 non-null   int64
#  6   DriverName  9921 non-null   object
#  7   Code        9921 non-null   object
#  8   Car         9920 non-null   object
#  9   Lap         9921 non-null   int64
#  10  TimeOfDay   9921 non-null   object
#  11  Time        9918 non-null   object
#  12  Total       9921 non-null   object
# dtypes: int64(6), object(7)
# memory usage: 1007.7+ KB

# %% [markdown]
# Berdasarkan data diatas, diketahui datasheet ini memiliki 9921 baris dan 13 kolom

# %% [markdown]
# ### Informasi Statistik Deskriptif

# %%
df.describe(include='all')
# Out:
#              RaceId     DriverId        Stops         Year     Race  \
# count   9921.000000  9921.000000  9921.000000  9921.000000     9921
# unique          NaN          NaN          NaN          NaN       27
# top             NaN          NaN          NaN          NaN  hungary
# freq            NaN          NaN          NaN          NaN      666
# mean     142.586231    42.631791     1.607600  2002.527467      NaN
# std       91.465460    85.404022     0.749017     4.816939      NaN
# min        1.000000     1.000000     1.000000  1994.000000      NaN
# 25%       68.000000    15.000000     1.000000  1998.000000      NaN
# 50%      129.000000    25.000000     1.000000  2003.000000      NaN
# 75%      213.000000    53.000000     2.000000  2007.000000      NaN
# max      355.000000   812.000000     6.000000  2010.000000      NaN
#
#                  No          DriverName  Code      Car          Lap TimeOfDay  \
# ...

# %% [markdown]
# 1. Count (kelengkapan data)
#
#     Berdasarkan data diatas, terdapat beberapa data yang hilang pada kolom *Car* dan *Time*
#
#
#     *   Car (9920)
#     *   Time (9918)
#
#         (Total 9921)
#
# 2. Mean (rata rata)
#
#     Mean *Stops* adalah 1.61 yang artinya rata rata pembalap melakukan 1-2 kali pitstop per balapan. Karena median (50%) = 1, berarti sebagaian besar pembalap hanya melakukan 1 kali pitstop.
#     Nilai maksimum menunjukkan angka 6 yang berarti ada beberapa balapan dengan strategi banyak pitstop atau kondisi tertentu.
#
#     Mean *Year* adalah 2002.52 yang artinya datasheet didominasi oleh data sekitar tahun 2002-2003 dengan rentang tahun dari 1994 sampai 2010.
#
#     Mean *Lap* adalah 29.61 yang artinya rata rata pitstop dilakukan pada lap ke 29-30 dengan median yang menunjukkan angka 28 yang artinya sebagian besar pitstop terjadi di pertengahan balapan.
#     Nilai maksimum menunjukkan angka 73 karena itu lap tertinggi.

# %% [markdown]
# ### Cek Tipe Data

# %%
df.dtypes
# Out:
# RaceId         int64
# DriverId       int64
# Stops          int64
# Year           int64
# Race          object
# No             int64
# DriverName    object
# Code          object
# Car           object
# Lap            int64
# TimeOfDay     object
# Time          object
# Total         object
# dtype: object

# %% [markdown]
# 0 RaceId dengan tipe data Integer64
#
# 1 DriverId dengan tipe data Integer64
#
# 2 Stops dengan tipe data Integer64
#
# 3 Year dengan tipe data Integer64
#
# 4 Race dengan tipe data Object
#
# 5 No dengan tipe data Integer64
#
# 6 DriverName dengan tipe data Object
#
# 7 Code dengan tipe data Object
#
# 8 Car dengan tipe data Object
#
# 9 Lap dengan tipe data Integer64
#
# 10 TimeOfDay dengan tipe data Object
#
# 11 Time dengan tipe data Object
#
# 12 Total dengan tipe data Object

# %% [markdown]
# ### Inconsistent Value

# %%
print(df['Car'].unique())
# Out:
# ['Larrousse Ford' 'Tyrrell Yamaha' 'McLaren Peugeot' 'Williams Renault'
#  'Minardi Ford' 'Sauber Mercedes' 'Ligier Renault' 'Benetton Ford'
#  'Footwork Ford' 'Jordan Hart' 'Ferrari' 'Simtek Ford' 'Lotus Mugen Honda'
#  'Pacific Ilmor' 'Benetton Renault' 'Ligier Mugen Honda'
#  'McLaren Mercedes' 'Footwork Hart' 'Sauber Ford' 'Forti Ford'
#  'Jordan Peugeot' 'Arrows Yamaha' 'Minardi Hart' 'Prost Mugen Honda'
#  'Stewart Ford' 'Tyrrell Ford' 'Sauber Petronas' 'Jordan Mugen Honda'
#  'Arrows' 'Benetton Playlife' 'Williams Mecachrome' 'Prost Peugeot'
#  'Williams Supertec' 'BAR Supertec' 'Minardi Fondmetal' 'Arrows Supertec'
#  'BAR Honda' 'Williams BMW' 'Jaguar Cosworth' 'Arrows Asiatech'
#  'Minardi European' 'Jordan Honda' 'Prost Acer' 'Toyota' 'Arrows Cosworth'
#  'Minardi Asiatech' 'Renault' 'Jordan Ford' 'Minardi Cosworth'
#  'Jordan Toyota' 'RBR Cosworth' 'Williams Cosworth' 'Super Aguri Honda'
#  'Honda' 'Sauber BMW' 'MF1 Toyota' 'RBR Ferrari' 'STR Cosworth'
# ...

# %% [markdown]
# Pada bagian ini terlihat konsisten dalam penamaan mobilnya, tidak ada kesalahan dalam penamaan. Tetapi, terdapat 1 missing value atau data yang kosong (nan) pada data diatas.

# %% [markdown]
# ### Missing Value

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#             Null Ratio in %
# RaceId             0.000000
# DriverId           0.000000
# Stops              0.000000
# Year               0.000000
# Race               0.000000
# No                 0.000000
# DriverName         0.000000
# Code               0.000000
# Car                0.010080
# Lap                0.000000
# TimeOfDay          0.000000
# Time               0.030239
# Total              0.000000

# %% [markdown]
# Pada tahap in, terdapat beberapa kolom yang kehilangan value nya. Dan terlhat bahwa kolom
#
#
# *   Car
#
#     Memiliki missing value sekitar 0.1%, yang dimana ini sangat kecil indikasi hilangnya data pada kolom tersebut sehingga tidak perlu ditangani atau dihapus.
#
#
# *   Time
#
#     Memiliki missing value sekitar 0.3%, yang dimana ini sangat kecil indikasi hilangnya data pada kolom tersebut sehingga tidak perlu ditangani atau dihapus.

# %% [markdown]
# ### Duplicated Values

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [RaceId, DriverId, Stops, Year, Race, No, DriverName, Code, Car, Lap, TimeOfDay, Time, Total]
# Index: []

# %% [markdown]
# Terlihat tidak ada Duplicated Value pada datasheet diatas.

# %% [markdown]
# ###Cek Outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom     Persentase Outliers
# RaceId               0.000000
# DriverId             1.945368
# Stops                1.703457
# Year                 0.000000
# No                   0.000000
# Lap                  0.000000

# %% [markdown]
# Berdasarkan data diatas terdapat outliers pada bagian *DriverId* dan *Stops*
#
# Pada kolom DriverId terdapat sekitar 1.95% data yang terdeteksi sebagai outlier.
# Outlier di sini bukan berarti pembalap aneh, tetapi karena metode statistik menganggap beberapa ID terlalu jauh dari median.
# Secara analisis bisnis, ini tidak relevan karena hanya kode identitas.
#
# Pada kolom Stops terdapat sekitar 1.70% data yang terdeteksi sebagai outlier.
# Yang artinya;
#
#
# *   Sebagian kecil pembalap melakukan pit stop jauh lebih banyak dibanding mayoritas.
# *   Mayoritas pembalap melakukan 1–2 pit stop.
# *   Beberapa kasus ekstrem bisa sampai 5–6 pit stop.
#
# Outliers ini kemungkinan terjadi karena masalah teknis mobil, strategi khusus, atau kondisi balapan tertentu. Outlier pada Stops ini menarik untuk dianalisis, bukan langsung dihapus.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['DriverId'])
plt.title('Boxplot of DriverId')
plt.ylabel('DriverId')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Stops'])
plt.title('Boxplot of Stops')
plt.ylabel('Stops')
plt.show()

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Perbandingan

# %%
# Hitung rata-rata pit stop per tahun
rata2_pitstop_tahun = df.groupby('Year')['Stops'].mean().sort_values()

plt.figure(figsize=(10,6))
sns.barplot(
    x=rata2_pitstop_tahun.index,
    y=rata2_pitstop_tahun.values,
    palette='viridis',
    hue=rata2_pitstop_tahun.index,
    legend=False
)

plt.title('Rata-rata Pit Stop per Tahun')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata Jumlah Pit Stop')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Grafik rata-rata jumlah pit stop per tahun menunjukkan adanya variasi strategi pit stop dari waktu ke waktu. Terlihat bahwa pada beberapa tahun tertentu rata-rata pit stop lebih tinggi dibanding tahun lainnya, yang menandakan adanya perubahan strategi atau kondisi balapan pada periode tersebut.
#
# Namun secara umum, rata-rata pit stop per tahun berada di kisaran 1 hingga 2 kali pit stop per balapan, sehingga dapat disimpulkan bahwa strategi yang paling sering digunakan dalam dataset ini adalah strategi satu kali pit stop. Perbedaan kecil antar tahun kemungkinan dipengaruhi oleh regulasi, kondisi lintasan, atau pendekatan strategi yang diterapkan oleh tim pada era tersebut.

# %% [markdown]
# ### Komposisi

# %%
# Hitung jumlah kejadian berdasarkan banyaknya pit stop
komposisi_pitstop = df['Stops'].value_counts().sort_index()

plt.figure(figsize=(8,8))
plt.pie(
    komposisi_pitstop,
    labels=komposisi_pitstop.index,
    autopct='%1.1f%%',
    startangle=140
)

plt.title('Komposisi Jumlah Pit Stop dalam Balapan')
plt.axis('equal')
plt.show()

# %% [markdown]
# Grafik pie chart menunjukkan komposisi jumlah pit stop yang dilakukan pembalap dalam satu balapan. Terlihat bahwa sebagian besar pembalap melakukan 1 kali pit stop, yang menjadi strategi paling dominan dalam dataset ini. Proporsi untuk 2 kali pit stop berada di urutan berikutnya, sedangkan 3 kali atau lebih hanya mencakup persentase kecil dari keseluruhan data.
#
# Hal ini menunjukkan bahwa strategi umum yang digunakan tim dalam balapan adalah strategi satu kali pit stop, karena dianggap lebih efisien dan meminimalkan waktu yang terbuang di pit lane. Sementara itu, jumlah pit stop yang lebih banyak kemungkinan terjadi karena kondisi khusus seperti masalah teknis, strategi agresif, atau situasi balapan tertentu.

# %% [markdown]
# ### Distribusi

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['Lap'], bins=20, kde=True)

plt.title('Distribusi Lap Saat Pit Stop Dilakukan')
plt.xlabel('Lap')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Distribusi lap menunjukkan bahwa pit stop paling sering dilakukan pada lap pertengahan balapan. Grafik biasanya akan membentuk pola terpusat di sekitar lap 25–35, sesuai dengan nilai rata-rata yang telah dianalisis sebelumnya. Hal ini menunjukkan bahwa mayoritas tim memilih melakukan pit stop setelah separuh balapan berjalan.
#
#
# Apakah distribusi ini normal?
# *   Terlihat lebih dari satu puncak, sekitar lap 20–25 dan lap 40–45.
# *   Distribusi tidak simetris sempurna.
# *   Ada ekor di sisi kanan (right tail) hingga lap 60–70.
#
# Ini menunjukkan distribusi tidak normal (tidak Gaussian).

# %% [markdown]
# ### Hubungan

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Lap', y='Stops', data=df)

plt.title('Hubungan antara Lap dan Jumlah Pit Stop')
plt.xlabel('Lap')
plt.ylabel('Jumlah Pit Stop')
plt.show()

# %% [markdown]
# Berdasarkan grafik scatter plot yang ditampilkan, terlihat bahwa hubungan antara lap dan jumlah pit stop tidak menunjukkan pola yang jelas. Titik-titik pada grafik tersebar secara acak dan tidak membentuk tren naik ataupun turun yang konsisten. Artinya, semakin besar nomor lap tidak selalu diikuti dengan bertambahnya jumlah pit stop.
#
# Sebagian besar data menunjukkan bahwa pit stop paling sering dilakukan sebanyak 2 hingga 3 kali, dan jumlah tersebut muncul hampir di seluruh rentang lap. Sementara itu, pit stop sebanyak 4 sampai 6 kali memang ada, tetapi jumlahnya lebih sedikit dan tidak terkonsentrasi pada pola tertentu. Pola yang terbentuk cenderung horizontal karena jumlah pit stop merupakan data diskrit (bilangan bulat), sehingga wajar jika titik-titiknya sejajar pada angka tertentu.
#
# Jika dilihat dari konteks balapan, kondisi ini tergolong normal. Jumlah pit stop tidak hanya dipengaruhi oleh posisi lap, tetapi juga banyak faktor lain seperti strategi tim, kondisi ban, adanya safety car, cuaca, maupun regulasi pada musim tertentu. Oleh karena itu, tidak ditemukannya hubungan linear yang kuat antara lap dan jumlah pit stop merupakan hal yang wajar.
#
# Secara keseluruhan, dapat disimpulkan bahwa variabel lap tidak secara langsung menentukan banyaknya pit stop yang dilakukan pembalap dalam balapan.

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Penanganan Tipe Data

# %%
df.dtypes
# Out:
# RaceId         int64
# DriverId       int64
# Stops          int64
# Year           int64
# Race          object
# No             int64
# DriverName    object
# Code          object
# Car           object
# Lap            int64
# TimeOfDay     object
# Time          object
# Total         object
# dtype: object

# %% [markdown]
# Kolom TimeOfDay dan Time tidak perlu dilakukan perubahan tipe data karena nilai pada kedua kolom tersebut hanya merepresentasikan informasi waktu perlombaan, bukan tanggal dan waktu lengkap (datetime). Saat kolom tersebut diubah ke tipe datetime, sistem secara otomatis menambahkan tanggal default (biasanya 1970-01-01 atau tanggal sistem lainnya), sehingga data ditampilkan seolah-olah terjadi pada waktu dini hari.
#
# Hal tersebut menyebabkan informasi menjadi kurang relevan dan berpotensi menimbulkan kesalahan interpretasi, karena fokus analisis hanya pada durasi atau waktu kejadian, bukan pada tanggal pelaksanaan. Oleh karena itu, tipe data object dipertahankan agar format waktu tetap sesuai dengan data asli dan tidak mengalami perubahan makna selama proses analisis.

# %% [markdown]
# ## Missing Value

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#             Null Ratio in %
# RaceId             0.000000
# DriverId           0.000000
# Stops              0.000000
# Year               0.000000
# Race               0.000000
# No                 0.000000
# DriverName         0.000000
# Code               0.000000
# Car                0.010080
# Lap                0.000000
# TimeOfDay          0.000000
# Time               0.030239
# Total              0.000000

# %%
df[df['Car'].isna()]
# Out:
#       RaceId  DriverId  Stops  Year     Race  No       DriverName Code  Car  \
# 8417      27         4      1  2008  germany   5  Fernando Alonso  ALO  NaN
#
#       Lap TimeOfDay   Time   Total
# 8417   38  14:54:31  24.27  24.270

# %% [markdown]
# Terdapat missing value pada kolom car. Disini saya memutuskan untuk mengisi kolom car yang ada data kosongnya dengan data 'unknown'. Kita tidak bisa seenaknya meimputasi kolom tersebut karena bisa menyesatkan analisis dan mengubah distribusi tim. Missing ini bisa terjadi karena data tidak tercatat.

# %%
df[df['Time'].isna()]
# Out:
#      RaceId  DriverId  Stops  Year     Race  No        DriverName Code  \
# 233     266       111      1  1994  hungary  32  Jean-Marc Gounon  GOU
# 242     266       112      1  1994  hungary   7   Philippe Alliot  ALL
# 267     266       105      2  1994  hungary  24  Michele Alboreto  ALB
#
#                  Car  Lap TimeOfDay Time   Total
# 233      Simtek Ford    9  14:13:24  NaN  00.000
# 242  McLaren Peugeot   21  14:30:03  NaN  00.000
# 267     Minardi Ford   54  15:17:33  NaN  44.556

# %% [markdown]
# Pada bagian Time, disini saya memutuskan untuk mengapus baris dikarenakan menurutsaya pada baris tersebut, driver mungkin saja terkena crash atau DNF dan tidak sempat melakukan pit stop.

# %%
#Perintah untuk menghapus baris
df = df.dropna(subset=['Time'])

# %%
#Perintah untuk memodifikasi kolom
df['Car'] = df['Car'].fillna('Unknown')
df = df.dropna(subset=['Time'])
# Out:
# /tmp/ipykernel_310/89824961.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Car'] = df['Car'].fillna('Unknown')

# %% [markdown]
# ## Inconsistent Value

# %%
print(df['Race'].unique())
# Out:
# ['pacific' 'san-marino' 'spain' 'canada' 'france' 'great-britain'
#  'germany' 'hungary' 'belgium' 'italy' 'portugal' 'europe' 'japan'
#  'australia' 'brazil' 'argentina' 'monaco' 'austria' 'luxembourg'
#  'malaysia' 'united-states' 'bahrain' 'china' 'turkey' 'singapore'
#  'abu-dhabi' 'south-korea']

# %% [markdown]
# Pada bagian ini sebenarnya tidak ada data yang tidak konsisten. Tetapi untuk penamaan sebuah daerah atau negara harus menggunakan huruf kapital di awal

# %%
df['Race'] = df['Race'].str.capitalize()
print(df['Race'].unique())
# Out:
# ['Pacific' 'San-marino' 'Spain' 'Canada' 'France' 'Great-britain'
#  'Germany' 'Hungary' 'Belgium' 'Italy' 'Portugal' 'Europe' 'Japan'
#  'Australia' 'Brazil' 'Argentina' 'Monaco' 'Austria' 'Luxembourg'
#  'Malaysia' 'United-states' 'Bahrain' 'China' 'Turkey' 'Singapore'
#  'Abu-dhabi' 'South-korea']

# %% [markdown]
# Berikut setelah dilakukan perbaikan.

# %% [markdown]
# ## Duplicated Value

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [RaceId, DriverId, Stops, Year, Race, No, DriverName, Code, Car, Lap, TimeOfDay, Time, Total]
# Index: []

# %% [markdown]
# Tidak ada data yang duplikat sehingga tidak perlu dilakukan perbaikan

# %% [markdown]
# ## Outliers

# %%
results = []
cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom     Persentase Outliers
# RaceId               0.000000
# DriverId             1.925791
# Stops                1.703973
# Year                 0.000000
# No                   0.000000
# Lap                  0.000000

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.boxplot(y=df['DriverId'])
plt.title('Outliers DriverId')

plt.subplot(1,2,2)
sns.boxplot(y=df['Stops'])
plt.title('Outliers Stops')

plt.tight_layout()
plt.show()

# %% [markdown]
# Outlier pada kolom DriverId dan Stop tidak perlu ditangani karena keduanya bukan kesalahan data. DriverId merupakan penanda identitas pembalap, sehingga nilai yang terlihat ekstrem hanyalah akibat dari perbedaan ID, bukan nilai numerik bermakna. Sementara itu, nilai pada kolom Stop masih valid secara konteks balapan karena dapat terjadi akibat strategi, penalti, atau kerusakan mobil. Oleh karena itu, outlier pada kedua kolom tersebut sebaiknya dipertahankan karena mengandung informasi yang sah dan penting.

# %% [markdown]
# ## Data Reduction

# %% [markdown]
# Disini saya akan menghapus kolom RaceId, DriverId, No, & Code.
# Reduksi data dilakukan untuk menyederhanakan dataset dan memfokuskan analisis pada variabel yang relevan dengan studi kasus performa balapan.
#
#
# *   RaceId dihapus karena hanya berfungsi sebagai identitas balapan dan tidak digunakan dalam analisis performa waktu, pit stop, atau mobil.
# *   DriverId dihapus karena analisis tidak berfokus pada identitas individual pembalap, melainkan pada pola umum performa balapan.
# *   No (nomor pembalap) bersifat administratif dan tidak memengaruhi performa atau hasil balapan.
# *   Code (kode singkatan pembalap) juga hanya berfungsi sebagai identitas dan tidak memiliki nilai analitis dalam studi kasus ini.

# %%
#Perintah untuk melakukan reduksi data
df = df.drop('RaceId', axis=1)
df = df.drop('DriverId', axis=1)
df = df.drop('No', axis=1)
df = df.drop('Code', axis=1)

# %%
df
# Out:
#       Stops  Year       Race         DriverName                   Car  Lap  \
# 0         1  1994    Pacific         Erik Comas        Larrousse Ford    1
# 1         1  1994    Pacific      Ukyo Katayama        Tyrrell Yamaha   17
# 2         1  1994    Pacific      Mika Hakkinen       McLaren Peugeot   18
# 3         1  1994    Pacific         Damon Hill      Williams Renault   18
# 4         1  1994    Pacific   Michele Alboreto          Minardi Ford   19
# ...     ...   ...        ...                ...                   ...  ...
# 9916      1  2010  Abu-dhabi      Jenson Button      McLaren Mercedes   39
# 9917      1  2010  Abu-dhabi         Timo Glock       Virgin Cosworth   40
# 9918      1  2010  Abu-dhabi  Heikki Kovalainen        Lotus Cosworth   41
# 9919      1  2010  Abu-dhabi      Robert Kubica               Renault   46
# 9920      1  2010  Abu-dhabi       Adrian Sutil  Force India Mercedes   47
#
#      TimeOfDay    Time   Total
# 0     14:01:34  49.111  49.111
# ...

# %% [markdown]
# Bisa diliat pada datashet diatas kalau kolom yang bersangkutan sudah dihapus.

# %% [markdown]
# ## Data Construction

# %% [markdown]
# Setelah kolom RaceId, DriverId, No, dan Code dihapus, dataset yang tersisa sudah berisi variabel inti yang langsung dapat digunakan untuk analisis performa balapan, seperti Car, Stop, dan Time. Kolom-kolom tersebut sudah memiliki makna yang jelas dan tipe data yang sesuai (misalnya Time sebagai durasi dan Stop sebagai jumlah pit stop), sehingga tidak diperlukan pembentukan variabel baru atau transformasi tambahan.

# %% [markdown]
# # Visualisasi

# %% [markdown]
# ## Bar Chart

# %%
# Bar Chart (Matplotlib): Perbandingan Jumlah Pit Stop per Race

# Menghitung total pit stop untuk setiap race
pitstop_race = df.groupby('Race')['Stops'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6)) # Ukuran
plt.bar(pitstop_race.index, pitstop_race.values, color='navy') # warna

plt.xlabel('Race') # keterangan X label
plt.ylabel('Total Pit Stop') # keterangan Y label
plt.title('Perbandingan Jumlah Pit Stop Berdasarkan Race') # Judul

plt.xticks(rotation=45, ha='right') # rotasi teks
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan grafik Perbandingan Jumlah Pit Stop Berdasarkan Race, terlihat bahwa beberapa race memiliki jumlah pit stop yang jauh lebih tinggi dibandingkan race lainnya. Race seperti Europe, Hungary, Spain, dan France berada di posisi teratas dengan jumlah pit stop paling banyak. Hal ini bisa terjadi karena beberapa faktor seperti strategi tim, kondisi sirkuit yang menuntut lebih banyak pergantian ban, atau durasi balapan yang lebih panjang.
#
# Sebaliknya, race seperti South Korea, Abu Dhabi, Luxembourg, dan Pacific memiliki jumlah pit stop yang jauh lebih sedikit. Hal ini kemungkinan dikarenakan jumlah data pada balapan tersebut lebih sedikit dibandingkan race lainnya. Jumlah data yang sedikit ini bisa dikarenakan balapan yang digelar di negara tersebut hanya beberapa tahun saja.
#
# Berdasarkan hasil analisis tersebut, beberapa tindakan yang dapat dilakukan adalah melakukan analisis lebih lanjut terhadap faktor-faktor yang mempengaruhi banyaknya pit stop pada suatu race, seperti jumlah lap, strategi tim, atau karakteristik sirkuit. Selain itu, perlu dilakukan pengecekan terhadap jumlah data pada setiap race untuk memastikan apakah perbedaan jumlah pit stop disebabkan oleh strategi balapan atau karena jumlah data yang tidak seimbang. Analisis lanjutan juga dapat dilakukan dengan membandingkan jumlah pit stop dengan variabel lain seperti tahun balapan atau performa pembalap, sehingga dapat diperoleh pemahaman yang lebih mendalam mengenai pola pit stop pada setiap race.

# %% [markdown]
# ## Line Chart

# %%
pitstop_per_year = df.groupby('Year')['Stops'].sum()

plt.figure(figsize=(10,6))
plt.plot(pitstop_per_year.index, pitstop_per_year.values, marker='o')

plt.title('Jumlah Pit Stop Berdasarkan Tahun Balapan')
plt.xlabel('Tahun')
plt.ylabel('Total Pit Stop')

plt.grid(True)
plt.show()

# %% [markdown]
# Berdasarkan grafik Jumlah Pit Stop Berdasarkan Tahun Balapan, terlihat bahwa jumlah pit stop mengalami fluktuasi dari tahun ke tahun. Pada periode awal, yaitu sekitar tahun 1994–1999, jumlah pit stop relatif lebih rendah dan stabil di bawah sekitar 800 pit stop. Kemudian mulai terjadi peningkatan secara bertahap pada awal tahun 2000-an. Puncak jumlah pit stop terjadi pada tahun 2004, dengan total sekitar 1600 pit stop, yang merupakan nilai tertinggi dalam dataset. Setelah tahun tersebut, jumlah pit stop cenderung mengalami penurunan secara bertahap hingga tahun 2010, meskipun masih terdapat sedikit kenaikan pada beberapa tahun tertentu. Pola ini menunjukkan bahwa strategi pit stop atau kondisi balapan dapat berubah seiring waktu, baik karena regulasi, strategi tim, maupun karakteristik balapan pada tahun tersebut.
#
#
# ---
#
# Tindakan berdasarkan insight diatas:
#
# *   Menganalisis tahun dengan pit stop tertinggi (2004)
# *   Membandingkan dengan variabel lain seperti jumlah race atau lap
# *   Mencari kemungkinan perubahan regulasi atau strategi
# *   Menggunakan analisis untuk memahami tren pit stop

# %% [markdown]
# ## Pie Chart

# %%
# Pie Chart: Proporsi Pit Stop Berdasarkan Race

pitstop_race = df.groupby('Race')['Stops'].sum().sort_values(ascending=False)
top3_race = pitstop_race.head(10)

plt.figure(figsize=(10, 8)) # Ukuran
top3_race.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Proporsi 10 Race dengan Jumlah Pit Stop Terbanyak') # Judul
plt.ylabel('') # Keterangan Y
plt.axis('equal')
plt.show()

# %% [markdown]
# Berdasarkan grafik tersebut, terlihat bahwa distribusi pit stop pada 10 race teratas relatif merata, dengan persentase yang tidak berbeda terlalu jauh antara satu race dengan race lainnya. Race seperti Europe dan Hungary memiliki proporsi sedikit lebih tinggi, yang menunjukkan bahwa balapan di sirkuit tersebut cenderung memiliki jumlah pit stop lebih banyak dibandingkan race lainnya dalam kategori ini. Hal ini bisa disebabkan oleh beberapa faktor seperti karakteristik sirkuit, strategi penggunaan ban, atau kondisi balapan yang menuntut pembalap melakukan pit stop lebih sering.
#
#
# ---
#
# Tindakan berdasarkan insight diatas:
#
# *   Membandingkan karakteristik sirkuit pada masing-masing race, seperti panjang lintasan atau jumlah tikungan, untuk melihat apakah faktor tersebut mempengaruhi jumlah pit stop.
# *   Melakukan analisis lebih lanjut terhadap race dengan proporsi pit stop tertinggi seperti Europe dan Hungary untuk mengetahui faktor yang menyebabkan pit stop lebih sering terjadi.
# *   Menggunakan hasil analisis ini untuk mempelajari pola strategi pit stop pada berbagai sirkuit, yang dapat membantu dalam memprediksi strategi balapan di masa mendatang.

# %% [markdown]
# ## Histogram

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Lap'], bins=20, kde=True, color='blue')
plt.title('Distribusi Lap Saat Pit Stop Dilakukan')
plt.xlabel('Lap')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Berdasarkan grafik Distribusi Lap Saat Pit Stop Dilakukan, terlihat bahwa pit stop paling sering terjadi pada lap tengah balapan, khususnya sekitar lap 18–25 dan lap 38–45. Hal ini menunjukkan adanya dua puncak distribusi (bimodal), yang menandakan bahwa sebagian besar pembalap melakukan pit stop pertama di sekitar lap 20-an dan pit stop berikutnya di sekitar lap 40-an.
#
# Selain itu, pit stop pada lap awal (di bawah lap 10) dan lap akhir (di atas lap 60) relatif lebih sedikit. Hal ini kemungkinan karena pada awal balapan pembalap masih menggunakan ban awal, sedangkan pada akhir balapan tim biasanya berusaha mempertahankan posisi tanpa melakukan pit stop tambahan kecuali terjadi kondisi tertentu.
#
#
# ---
#
# Action berdasarkan insight diatas:
#
# *   Melakukan analisis lebih lanjut terhadap strategi pit stop tim, khususnya pada lap sekitar 20 dan 40 yang menjadi titik paling sering terjadinya pit stop.
# *   Membandingkan jumlah pit stop dengan variabel lain seperti race atau driver, untuk mengetahui apakah pola ini konsisten pada semua balapan atau hanya pada sirkuit tertentu.
# *   Mengkaji apakah jenis sirkuit atau kondisi lintasan mempengaruhi waktu pit stop yang paling sering dilakukan.
# *   Menggunakan pola distribusi ini untuk memprediksi strategi pit stop pada balapan berikutnya, terutama pada fase tengah balapan.

# %% [markdown]
# ## Box Plot

# %%
VARIABEL1 = df['Race'].value_counts().head(5).index
VARIABEL2 = df[df['Race'].isin(VARIABEL1)]

plt.figure(figsize=(12, 7)) # Ukuran figure
VARIABEL2.boxplot(column='Lap', by='Race', ax=plt.gca(), grid=False, patch_artist=True, medianprops=dict(color='red'))
plt.title('Distribusi Lap Pit Stop pada 5 Race Terbanyak', fontsize=16) # Judul
plt.xlabel('Race', fontsize=12) # X Keterangan
plt.ylabel('Lap', fontsize=12) # Y Keterangan
plt.xticks(rotation=45, ha='right')
plt.suptitle('') # Menghilangkan judul default dari boxplot.by
plt.tight_layout()

plt.show()

# %% [markdown]
# Visualisasi boxplot menunjukkan bahwa distribusi lap pit stop pada lima race memiliki pola yang berbeda-beda. Race Hungary memiliki variasi lap pit stop yang paling lebar dibandingkan race lainnya, terlihat dari rentang data yang sangat besar dari lap awal hingga lap akhir serta median yang berada di sekitar lap 32. Hal ini mengindikasikan bahwa strategi pit stop pada race ini sangat beragam dan fleksibel. Sementara itu, race Japan memiliki median yang lebih rendah dibandingkan race lain, sekitar lap 25, yang menunjukkan kecenderungan pit stop dilakukan lebih awal dengan distribusi yang relatif lebih sempit. Race Europe, Great Britain, dan Spain memiliki pola distribusi yang cukup mirip dengan median berkisar antara lap 27 hingga lap 30, yang menandakan strategi pit stop yang lebih stabil dan konsisten. Selain itu, terlihat beberapa pit stop yang terjadi sangat awal maupun sangat akhir yang kemungkinan dipengaruhi oleh faktor seperti safety car, kerusakan kendaraan, atau strategi balapan tertentu.
#
# ---
# Action berdasarkan insight diatas:
#
# *   Mengoptimalkan strategi early pit stop pada race seperti Japan yang menunjukkan kecenderungan pit stop lebih awal.
# *   Melakukan analisis lanjutan terhadap pit stop yang terjadi sangat awal atau sangat akhir untuk mengidentifikasi pengaruh safety car atau kejadian balapan lainnya.
# *   Gunakan median lap pit stop pada setiap race sebagai acuan dasar untuk menentukan pit stop window yang optimal.

# %% [markdown]
# ## Scatter Plot

# %%
plt.figure(figsize=(10, 6)) # Ukuran
plt.scatter(df['Lap'], df['Stops'], alpha=0.7, color='teal') # Color (Warna)
plt.title('Hubungan antara Lap dan Jumlah Pit Stop', fontsize=16) # Judul
plt.xlabel('Lap', fontsize=12) # X Keterangan
plt.ylabel('Jumlah Pit Stop', fontsize=12) # Y Keterangan
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Visualisasi scatter plot menunjukkan hubungan antara lap balapan dan jumlah pit stop yang dilakukan. Dari grafik terlihat bahwa sebagian besar pit stop terjadi pada rentang lap menengah hingga akhir balapan, sekitar lap 20 hingga lap 60. Jumlah pit stop yang paling umum dilakukan adalah 2 hingga 3 kali, yang terlihat dari kepadatan titik pada area tersebut. Pit stop dengan jumlah 1 biasanya terjadi pada strategi yang lebih konservatif atau pada balapan dengan degradasi ban yang lebih rendah. Sementara itu, jumlah pit stop yang lebih banyak seperti 4 hingga 6 kali cenderung muncul pada lap menengah hingga akhir dan jumlahnya relatif lebih sedikit, yang kemungkinan disebabkan oleh strategi agresif, kondisi ban yang cepat aus, atau faktor tak terduga seperti safety car atau kerusakan kendaraan. Secara keseluruhan, grafik ini menunjukkan bahwa semakin panjang jalannya balapan, semakin besar kemungkinan tim melakukan lebih dari satu pit stop sebagai bagian dari strategi manajemen ban.
#
# ---
# *   Menggunakan strategi pit stop 2–3 kali sebagai strategi dasar karena merupakan pola yang paling umum terjadi.
# *   Menganalisis lebih lanjut faktor yang menyebabkan pit stop lebih dari 3 kali, seperti degradasi ban, safety car, atau strategi agresif.
# *   Mengoptimalkan waktu pit stop pada rentang lap menengah hingga akhir (sekitar lap 20–60) untuk memaksimalkan performa ban.
# *   Mengembangkan model prediksi pit stop berdasarkan lap balapan untuk membantu pengambilan keputusan strategi saat race berlangsung.
# *   Mengombinasikan analisis ini dengan data lain seperti tipe ban, kondisi lintasan, dan posisi pembalap untuk mendapatkan strategi pit stop yang lebih optimal.

# %% [markdown]
# ## Heat Map

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['Lap', 'Stops']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Heatmap Korelasi antara Lap dan Stops')
plt.show()

# %% [markdown]
# Heatmap korelasi menunjukkan bahwa terdapat hubungan positif antara lap dan jumlah pit stop dengan nilai korelasi sebesar 0,61. Nilai ini menunjukkan tingkat korelasi yang cukup kuat (moderate positive correlation), yang berarti semakin tinggi lap dalam balapan, semakin besar kemungkinan jumlah pit stop yang dilakukan juga meningkat. Hal ini masuk akal karena seiring bertambahnya lap, ban akan mengalami degradasi sehingga tim perlu melakukan pit stop untuk mengganti ban atau melakukan penyesuaian strategi. Meskipun demikian, nilai korelasi yang tidak terlalu tinggi menunjukkan bahwa jumlah pit stop tidak hanya dipengaruhi oleh jumlah lap saja, tetapi juga oleh faktor lain seperti strategi tim, kondisi lintasan, jenis ban, serta kejadian dalam balapan seperti safety car atau kerusakan kendaraan.
#
# ---
# Action berdasarkan insight diatas:
#
# *   Menggunakan informasi korelasi ini untuk memperkirakan kemungkinan jumlah pit stop berdasarkan progres lap dalam balapan.
# *   Mengembangkan model analisis yang menggabungkan variabel lain seperti jenis ban, kondisi lintasan, dan strategi tim untuk meningkatkan akurasi prediksi pit stop.
# *   Melakukan segmentasi analisis berdasarkan fase balapan (awal, tengah, akhir) untuk memahami pola pit stop secara lebih detail.
# *   Menggunakan hasil analisis ini sebagai dasar dalam simulasi strategi pit stop untuk mengoptimalkan performa balapan.
# *   Mengintegrasikan analisis korelasi dengan visualisasi lain seperti scatter plot atau distribusi pit stop agar pengambilan keputusan strategi lebih komprehensif.
